# %% [markdown]
# # Rock Physics Modelling

# %% [markdown]
# This tutorial demonstrates how to create rock physics models and apply them to well log analysis to quantify seismic responses.

# %%
#Import libraries
from pyavo.seismodel import rpm
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Read well Data

# %%
well = pd.read_csv('./data/qsiwell5.csv', index_col=0)
well.head()
# Out:
#                 DT      DTS       GR    RHO           VP          VS  \
# DEPTH
# 2100.0720  127.134  312.372   86.778  2.262  2397.470386  975.759671
# 2100.2244  128.017  313.654   90.658  2.260  2380.933782  971.771442
# 2100.3767  128.512  313.706  102.479  2.267  2371.762948  971.610361
# 2100.5293  128.534  316.362  114.549  2.272  2371.356995  963.453259
# 2100.6816  128.309  321.356  118.948  2.275  2375.515357  948.480813
#
#                VPVS           IP           IS       VSH      RHOm  RHOf  \
# DEPTH
# 2100.0720  2.457030  5423.078012  2207.168376  0.484501  2.727520  1.09
# 2100.2244  2.450096  5380.910348  2196.203460  0.537838  2.736054  1.09
# 2100.3767  2.441064  5376.786604  2202.640689  0.700337  2.762054  1.09
# 2100.5293  2.461310  5387.723093  2188.965805  0.866259  2.788601  1.09
# 2100.6816  2.504548  5404.297438  2157.793849  0.926730  2.798277  1.09
#
#                PHIE
# DEPTH
# 2100.0720  0.284284
# 2100.2244  0.289209
# 2100.3767  0.296075
# 2100.5293  0.304133
# 2100.6816  0.306319

# %% [markdown]
# 2. Define model parameters

# %%
vshale = well.VSH # Volume of shale
vp = well.VP # P-wave velocity
vs = well.VS # S-wave velocity
imp = well.IP # Acoustic impedance
poro = well.PHIE # Porosity
rho = well.RHO # Density
vpvs = well.VPVS #Vp/Vs

# %% [markdown]
# 3. Display key input logs for Rock Physics Modelling

# %%
rpm.plot_log(well, vshale, vp, vs, imp, vpvs, poro, rho, 
             z_init=2100, z_final=2250, shale_cutoff=0.5, 
             sand_cutoff=0.3)

# %% [markdown]
# 4. Compute Voigt-Reuss-Hill Avergae

# %%
# Data
rho_qtz = 2.6 # Density of quartz
k_qtz = 37 # Bulk modulus of quartz
mu_qtz = 44 # Shear modulus of quartz
rho_sh = 2.8 # Denisty of shale
k_sh = 15 # Bulk modulus of shale
mu_sh = 5 # Shear modulus of shale
rho_br = 1.1 # Density of brine
k_br = 2.8 # Bulk modulus of brine
rho_o = 0.8 # Density of oil
k_o = 0.9 # Bulk modulus of oil
rho_g = 0.2 # Density of gas
k_g = 0.06 # Bulk modulus of gas
phic = 0.4 #Critical porosity
f = 1

phi = np.linspace(0.01, 0.4) #porosity
NG = np.linspace(0.6,1.0,5) #Net to Gross

z1, z2, cutoff_sand, cutoff_shale = 2100, 2250, 0.3, 0.5 

P, cp_ssm, cn_ssm, cp_stm, cn_stm = 45, 0.5, 12, 0.4, 8

eff_phi = well.PHIE

# %%
rpm.voigt_reuss(mod1=k_qtz,mod2=k_sh,vfrac=0.8) #Bulk modulus
# Out:
# (32.6, 28.608247422680414, 30.604123711340208)

# %%
rpm.voigt_reuss(mod1=mu_qtz,mod2=mu_sh,vfrac=0.8) #Shear modulus
# Out:
# (36.2, 17.1875, 26.69375)

# %% [markdown]
# 5. Plot Soft and Stiff Sand Rock Physics Models for different mineralogies

# %%
rpm.plot_rpm(well, k_qtz, mu_qtz, k_sh, mu_sh, rho_sh, rho_qtz, 
             k_br, rho_br, phi, NG, vshale, z1, z2, cutoff_sand, 
             cutoff_shale, P, cp_ssm, cn_ssm, cp_stm, cn_stm, eff_phi, vp)

# %% [markdown]
# 6. Explore plot of Rock Physics Template

# %%
ip, vpvs = rpm.plot_rpt(model='soft', fluid='oil') #Soft sand model, fluid=oil

# %%
ip, vpvs = rpm.plot_rpt(model='stiff', fluid='oil') #Stiff sand model, fluid=oil

# %%
ip, vpvs = rpm.plot_rpt(model='soft', fluid='gas') #Soft sand model, fluid=gas

# %%
ip, vpvs = rpm.plot_rpt(model='stiff', fluid='gas') #Stiff sand model, fluid=gas
